# %% [markdown]
# # Train Startup Suitability Model
#
# Train MVP regressors against the rule-based target. Replace the target with real outcome data before production use.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from ml.train_startup_suitability import train_startup_suitability_model

train_startup_suitability_model()
