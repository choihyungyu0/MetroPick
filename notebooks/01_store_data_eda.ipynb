# %% [markdown]
# # Store Data EDA
#
# Explore the bundled Gwangju store fixture before connecting real public-data feeds.

# %%
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
stores = pd.read_csv(PROJECT_ROOT / 'data/raw/stores/sample_gwangju_store_data.csv')
stores.head()

# %%
stores['business_medium'].value_counts()
